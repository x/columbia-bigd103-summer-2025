# %% [markdown]
# # Shopping List App
#
# Build a simple shopping list application that helps users keep track of items they need to buy. This assignment will practice lists, functions, and user interaction.
#
# ## Core Requirements
#
# Your shopping list app must have these features:
#
# ### Part 1: Basic Functions
#
# Write the following functions:
#
# 1. **`display_list(shopping_list)`** - Shows all items in the list
#    ```python
#    # Example output:
#    Shopping List:
#    1. Milk
#    2. Bread
#    3. Eggs
#    ```
#
# 2. **`add_item(shopping_list, item)`** - Adds an item to the list
#    - Don't add duplicates (check if item already exists)
#    - Return True if added, False if duplicate
#
# 3. **`remove_item(shopping_list, item_number)`** - Removes item by position
#    - Remember: display shows 1-based numbers, but lists are 0-indexed!
#    - Return True if removed, False if invalid number
#
# ### Part 2: Main Program
#
# Create a menu-driven program:
# ```
# === SHOPPING LIST MANAGER ===
# 1. View list
# 2. Add item
# 3. Remove item
# 4. Clear list
# 5. Exit
#
# Enter choice:
# ```
#
# **Requirements:**
# - The program should loop until user chooses to exit
# - Handle invalid menu choices gracefully
# - Start with an empty list
#
# ## Sample Interaction
#
# ```
# === SHOPPING LIST MANAGER ===
# 1. View list
# 2. Add item
# 3. Remove item
# 4. Clear list
# 5. Exit
#
# Enter choice: 2
# Enter item to add: Milk
# Added "Milk" to your list!
#
# Enter choice: 2
# Enter item to add: Bread
# Added "Bread" to your list!
#
# Enter choice: 1
#
# Shopping List:
# 1. Milk
# 2. Bread
#
# Enter choice: 3
# Enter item number to remove: 1
# Removed "Milk" from your list!
#
# Enter choice: 5
# Goodbye!
# ```
#
# ## Bonus Features
#
# ### Level 1: Enhanced Features
# - Add **`mark_purchased(shopping_list, item_number)`** to mark items as bought
#   - Display purchased items with ✓ or [X]
#   - Keep them in the list but show they're done
# - Add item quantities (e.g., "Milk (2 gallons)")
# - Sort list alphabetically
#
# ### Level 2: Categories
# - Organize items by category (Produce, Dairy, Meat, etc.)
# - Display items grouped by category
# - Add category when adding items

# %%
def display_list(shopping_list):
    """Display all items in the shopping list"""
    # TODO: Your code here
    pass

def add_item(shopping_list, item):
    """Add item to list if not duplicate"""
    # TODO: Your code here
    pass

def remove_item(shopping_list, item_number):
    """Remove item at given position"""
    # TODO: Your code here
    pass

def main():
    shopping_list = []

    while True:
        print("\n=== SHOPPING LIST MANAGER ===")
        print("1. View list")
        print("2. Add item")
        print("3. Remove item")
        print("4. Clear list")
        print("5. Exit")

        choice = input("\nEnter choice: ")

        # TODO: Handle each choice

# Run the program
main()
