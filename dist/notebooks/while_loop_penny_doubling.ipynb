# %% [markdown]
# # Do Now: The Penny Doubling Challenge
#
# Let's practice `while` loops with counters by exploring an age-old question: Would you rather have $1 million right now, or start with a penny that doubles every day for 30 days?
#
# ## Your Mission
#
# Use `while` loops to calculate how much money you'd have if you started with a penny that doubles each day.
#
# Write a program that:
# 1. Starts with 1 cent (0.01 dollars)
# 2. Doubles the amount each day
# 3. Stops after 30 days
# 4. Shows the final amount
#
# Expected output format:
# ```
# Starting with a penny...
# Day 1: $0.01
# Day 2: $0.02
# Day 3: $0.04
# ...
# ```
#
# ### Bonus
#
# 1. If you become a millionarie before day 30, stop before that happens.
# 2. Calculate how many days to hit $1 billion.

# %%
money = 0.01  # Start with a penny
day = 1

# Use a while loop here to double money every day for 30 days

print(f"After 30 days, you have: ${money:.2f}")
